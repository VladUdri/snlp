# %%
# !pip3 install transformers
# !pip3 install scikit-multilearn
# !pip3 install iterative-stratification
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-multilearn in /usr/local/lib/python3.9/dist-packages (0.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: iterative-stratification in /usr/local/lib/python3.9/dist-packages (0.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->iterative-stratification) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->iterative-stratification) (1.1.1)

# %%
# !apt-get install -y --no-install-recommends libcudnn8
# !apt-mark hold libcudnn8

# !nvcc --version
# !echo "cudnn version:"
# !cat /usr/local/cuda/include/cudnn_version.h | grep CUDNN_MAJOR -A 2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-525
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8 libcudnn8-dev
# 2 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# E: Held packages were changed and -y was used without --allow-change-held-packages.
# libcudnn8 was already set on hold.
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# cudnn version:
# cat: /usr/local/cuda/include/cudnn_version.h: No such file or directory

# %%
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load the dataset
df = pd.read_csv("./data_balanced.csv")
df = df.drop(columns=['None', 'powerlabel'])
df.dropna(inplace=True)

# Convert labels to tensor
labels = df.iloc[:, 1:].values

# Initialize tokenizer
tokenizer = AutoTokenizer.from_pretrained('publichealthsurveillance/PHS-BERT')

# Tokenize input sentences and create attention masks
input_ids = []
attention_masks = []

for sentence in df['Content']:
    encoded_dict = tokenizer.encode_plus(sentence, add_special_tokens=True, max_length=387, padding='max_length', truncation=True, return_attention_mask=True, return_tensors='tf')
    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])

# Convert input_ids and attention_masks to tensors
input_ids = tf.concat(input_ids, axis=0)
attention_masks = tf.concat(attention_masks, axis=0)

# Prepare data for train-test split
X = np.hstack([input_ids.numpy(), attention_masks.numpy()])
y = labels

# Split the data into training and testing sets
train_X, test_X, train_y, test_y, train_index, test_index = train_test_split(X, y, df.index, test_size=0.2, random_state=42)

train_input_ids, train_attention_masks = train_X[:, :387], train_X[:, 387:]
test_input_ids, test_attention_masks = test_X[:, :387], test_X[:, 387:]
train_labels, test_labels = train_y, test_y

# Define the path to save the model
model_path = "./trained_model"

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=2)

# Define model checkpoint callback
model_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', save_best_only=True)

# Check if a saved model exists and load it, if it does
# Check if a saved model exists and load it, if it does
if os.path.exists(model_path):
    model = TFAutoModelForSequenceClassification.from_pretrained(model_path)
else:
    # Initialize the model
    model = TFAutoModelForSequenceClassification.from_pretrained('publichealthsurveillance/PHS-BERT', num_labels=labels.shape[1], from_pt=True)

    # Compile the model for training
    optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
    loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    metric = tf.keras.metrics.BinaryAccuracy('accuracy')
    model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

    # Train the model
    history = model.fit(
        [train_input_ids, train_attention_masks],
        train_labels,
        epochs=1,
        batch_size=16,
        validation_data=(
            [test_input_ids, test_attention_masks],
            test_labels
        ),
        callbacks=[early_stopping, model_checkpoint]
    )
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 1993/1993 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9284
# WARNING:absl:Found untraced functions such as embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses, pooler_layer_call_fn while saving (showing 5 of 828). These functions will not be directly callable after loading.
# 1993/1993 [==============================] - 1209s 560ms/step - loss: 0.1894 - accuracy: 0.9284 - val_loss: 0.0939 - val_accuracy: 0.9707

# %%
import tensorflow as tf
from transformers import TFBertForSequenceClassification

model.save_pretrained("./trained_model")
# Check if a saved model exists and load it
model_path = "./trained_model"

if os.path.exists(model_path):
    model = TFBertForSequenceClassification.from_pretrained(model_path)
else:
    print("Model not found. Please train the model and save it first.")

# Compile the loaded model
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)
metric = tf.keras.metrics.BinaryAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

# Convert test_input_ids and test_attention_masks to tensors
test_input_ids = tf.convert_to_tensor(test_input_ids)
test_attention_masks = tf.convert_to_tensor(test_attention_masks)

# Evaluate the model on the test data
evaluation_results = model.evaluate([test_input_ids, test_attention_masks], test_labels, batch_size=16)
print("Test loss: ", evaluation_results[0])
print("Test accuracy: ", evaluation_results[1])
# Out:
# Some layers from the model checkpoint at ./trained_model were not used when initializing TFBertForSequenceClassification: ['dropout_73']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at ./trained_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.
# 499/499 [==============================] - 91s 171ms/step - loss: 0.0939 - accuracy: 0.9707
# Test loss:  0.0938863605260849
# Test accuracy:  0.970672070980072

# %%
# Evaluate the model on the test set
predictions = model.predict([test_input_ids, test_attention_masks])
logits = predictions.logits  # Access the logits from the output object
threshold = 0.5
predicted_labels = (np.array(logits, dtype=float) >= threshold).astype(int)
true_labels = test_labels
# Out:
# 250/250 [==============================] - 81s 302ms/step

# %%
from sklearn.metrics import classification_report
# Calculate metrics (precision, recall, F1 score)
label_names = ['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4', 'symptom_5', 'symptom_6', 'symptom_7']
report = classification_report(true_labels, predicted_labels, output_dict=True, zero_division=0, target_names=label_names)

# Convert the report dictionary to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the classification report as a table
print("Classification report:")
print(report_df)
# Out:
# Classification report:
#               precision    recall  f1-score  support
# symptom_1      0.990394  0.977057  0.983681   2005.0
# symptom_2      0.985138  0.977357  0.981232   1899.0
# symptom_3      0.982117  0.929127  0.954887   2187.0
# symptom_4      0.960621  0.805268  0.876111   2999.0
# symptom_5      0.984767  0.867403  0.922367   2534.0
# symptom_6      0.995485  0.947877  0.971098   1861.0
# symptom_7      0.986700  0.942145  0.963908   2126.0
# micro avg      0.982595  0.911345  0.945630  15611.0
# macro avg      0.983603  0.920891  0.950469  15611.0
# weighted avg   0.982066  0.911345  0.944539  15611.0
# samples avg    0.528464  0.524386  0.524645  15611.0

# %%
from sklearn.metrics import precision_recall_fscore_support, hamming_loss, jaccard_score

# Micro-averaged precision, recall, and F1 score
micro_precision, micro_recall, micro_f1, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='micro')
print("Micro-averaged Precision:", micro_precision)
print("Micro-averaged Recall:", micro_recall)
print("Micro-averaged F1 score:", micro_f1)

# Macro-averaged precision, recall, and F1 score
macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='macro')
print("Macro-averaged Precision:", macro_precision)
print("Macro-averaged Recall:", macro_recall)
print("Macro-averaged F1 score:", macro_f1)

# Hamming Loss
hamming = hamming_loss(true_labels, predicted_labels)
print("Hamming Loss:", hamming)

# Jaccard Score
jaccard = jaccard_score(true_labels, predicted_labels, average='samples')
print("Jaccard Score:", jaccard)
# Out:
# Micro-averaged Precision: 0.9825954831134747
# Micro-averaged Recall: 0.911344564729998
# Micro-averaged F1 score: 0.9456297773346626
# Macro-averaged Precision: 0.9836030987900867
# Macro-averaged Recall: 0.9208906590716746
# Macro-averaged F1 score: 0.9504690473788363
# Hamming Loss: 0.02932793144864923
# Jaccard Score: 0.5208453590998452
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 in samples with no true or predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix
import matplotlib.pyplot as plt


# Calculate the confusion matrix
# Since this is a multi-label classification problem, we'll use multilabel_confusion_matrix
cm = multilabel_confusion_matrix(test_labels, predicted_labels)

# Plot the confusion matrix
# label_names = ['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4', 'symptom_5', 'symptom_6', 'symptom_7']

# Create a grid for subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))
fig.delaxes(axes[1, 3])  # remove the last subplot (as we have only 7 labels)

for i, (label_name, ax) in enumerate(zip(label_names, axes.flat)):
    sns.heatmap(cm[i], annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(f'{label_name}')

plt.tight_layout()
plt.show()

# %%
# Create an empty list to store the normalized confusion matrices for each label
confusion_matrices = []

# Calculate the confusion matrices for each label and normalize them
for i in range(7):
    cm = confusion_matrix(true_labels[:, i], predicted_labels[:, i])
    cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
    confusion_matrices.append(cm_normalized)

# Combine the normalized confusion matrices into a single array
combined_cm = np.concatenate(confusion_matrices, axis=1)

# Plot the heatmap
plt.figure(figsize=(15, 5))
sns.heatmap(combined_cm, annot=True, cmap="coolwarm", fmt=".2f", cbar=False, xticklabels=label_names, yticklabels=["Negative", "Positive"] * 7)

plt.title("Normalized Confusion Matrices for All Labels")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate metrics (precision, recall, F1 score)
label_names = ['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4', 'symptom_5', 'symptom_6', 'symptom_7']
report = classification_report(true_labels, predicted_labels, output_dict=True, zero_division=0, target_names=label_names)

# Extract F1 scores for each label
f1_scores = {label: report[label]['f1-score'] for label in label_names}

# Create a heatmap of F1 scores
f1_scores_matrix = np.array(list(f1_scores.values())).reshape(1, -1)
plt.figure(figsize=(10, 1))
sns.heatmap(f1_scores_matrix, annot=True, fmt='.2f', xticklabels=label_names, yticklabels=['F1 Score'], cmap='coolwarm', vmin=0, vmax=1)
plt.title('F1 Scores Heatmap')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def all_correct_percentage(y_true, y_pred):
    correct = np.all(y_true == y_pred, axis=1)
    percentage = np.sum(correct) / len(correct)
    return percentage

# Calculate the percentage of instances with all labels predicted correctly
all_correct_pct = all_correct_percentage(true_labels, predicted_labels)

# Visualize the percentage
fig, ax = plt.subplots(figsize=(6, 1))
ax.barh(['All Correct'], [all_correct_pct], color='blue')
ax.set_xlim(0, 1)
ax.set_xlabel('Percentage')
ax.set_title('Percentage of Instances with All Labels Predicted Correctly')
plt.show()

def exact_match_ratio(true_labels, predicted_labels):
    assert true_labels.shape == predicted_labels.shape
    return np.all(true_labels == predicted_labels, axis=1).mean()

exact_match = exact_match_ratio(true_labels, predicted_labels)
print(f"Exact Match Ratio: {exact_match:.2f}")
# Out:
# Exact Match Ratio: 0.84

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract precision, recall, and F1 score from the classification report
precision = [report[label]['precision'] for label in label_names]
recall = [report[label]['recall'] for label in label_names]
f1_score = [report[label]['f1-score'] for label in label_names]

# Visualize the metrics together
fig, ax = plt.subplots(figsize=(10, 5))
labels = np.arange(len(label_names))
width = 0.2

rects1 = ax.bar(labels - 1.5 * width, precision, width, label='Precision')
rects2 = ax.bar(labels - 0.5 * width, recall, width, label='Recall')
rects3 = ax.bar(labels + 0.5 * width, f1_score, width, label='F1 Score')
rects4 = ax.bar(labels + 1.5 * width, [evaluation_results[1]] * len(labels), width, label='Accuracy')

ax.set_xlabel('Labels')
ax.set_xticks(labels)
ax.set_xticklabels(label_names)
ax.set_ylabel('Score')
ax.set_title('Metrics by Label')
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords='offset points',
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.show()

# %%
import seaborn as sns
from collections import Counter

def label_combination_counts(labels):
    label_counts = Counter()
    for row in labels:
        label_counts[tuple(row)] += 1
    return label_counts

true_label_counts = label_combination_counts(true_labels)
predicted_label_counts = label_combination_counts(predicted_labels)

label_combinations = sorted(set(list(true_label_counts.keys()) + list(predicted_label_counts.keys())))
true_label_freq = [true_label_counts[combination] for combination in label_combinations]
predicted_label_freq = [predicted_label_counts[combination] for combination in label_combinations]

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 8))
fig.suptitle('Heatmap of Label Combinations')

sns.heatmap([true_label_freq], xticklabels=label_combinations, yticklabels=["True"], annot=True, fmt="d", cmap="YlGnBu", ax=ax1)
sns.heatmap([predicted_label_freq], xticklabels=label_combinations, yticklabels=["Predicted"], annot=True, fmt="d", cmap="YlGnBu", ax=ax2)

plt.show()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

# Calculate ROC curve and AUC for each label

n_classes = train_labels.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

# Rest of the code remains the same


for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(true_labels[:, i], logits[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Label {i + 1} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Label')
plt.legend(loc="lower right")
plt.show()

# %%
# Calculate Precision-Recall curve and AUC-PR for each label
precision = dict()
recall = dict()
average_precision = dict()

for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(true_labels[:, i], logits[:, i])
    average_precision[i] = average_precision_score(true_labels[:, i], logits[:, i])

# Plot Precision-Recall curve
plt.figure()
for i in range(n_classes):
    plt.plot(recall[i], precision[i], label=f'Label {i + 1} (AUC-PR = {average_precision[i]:.2f})')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for Each Label')
plt.legend(loc="upper right")
plt.show()

# %%
from transformers import TFBertModel
import tensorflow as tf
# Get the attention weights from BERT
def get_attention_weights(input_ids, attention_masks):
    bert = TFBertModel.from_pretrained('bert-base-uncased', output_attentions=True)
    outputs = bert(input_ids, attention_mask=attention_masks)
    attentions = outputs.attentions
    return attentions

# Analyze the attention weights for a specific sample
sample_index = 0  # Change this to analyze different samples
input_id_sample = tf.reshape(test_input_ids[sample_index], (1, -1))
attention_mask_sample = tf.reshape(test_attention_masks[sample_index], (1, -1))

# Convert tensors to the appropriate format
input_id_sample = tf.convert_to_tensor(input_id_sample)
attention_mask_sample = tf.convert_to_tensor(attention_mask_sample)

attentions = get_attention_weights(input_id_sample, attention_mask_sample)

# Get the words from the input_ids
tokens = tokenizer.convert_ids_to_tokens(input_id_sample[0])

# Print the attention weights for the sample
for i, attention in enumerate(attentions):
    print(f"Layer {i + 1}")
    print(tokens)
    print(attention[0][0].numpy())
    print("\n")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/536M [00:00<?, ?B/s]
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Layer 1
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.05087759 0.02965748 0.04138515 ... 0.         0.         0.        ]
#  [0.05188229 0.03829655 0.11705848 ... 0.         0.         0.        ]
#  [0.05062124 0.07086996 0.04347775 ... 0.         0.         0.        ]
#  ...
#  [0.0231433  0.07560749 0.0163552  ... 0.         0.         0.        ]
#  [0.03410037 0.0855526  0.01370921 ... 0.         0.         0.        ]
#  [0.0571708  0.08290213 0.01887124 ... 0.         0.         0.        ]]
#
#
# Layer 2
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.07361692 0.00937114 0.14914733 ... 0.         0.         0.        ]
#  [0.17886491 0.03089087 0.26791558 ... 0.         0.         0.        ]
#  [0.6260088  0.01978565 0.062856   ... 0.         0.         0.        ]
#  ...
#  [0.7368645  0.00269477 0.07490095 ... 0.         0.         0.        ]
#  [0.79008025 0.00258346 0.06688547 ... 0.         0.         0.        ]
#  [0.751795   0.00283754 0.07589971 ... 0.         0.         0.        ]]
#
#
# Layer 3
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[9.6819413e-01 2.3416703e-04 2.7990439e-03 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [1.0103329e-06 8.0762288e-07 9.9998319e-01 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [1.4171798e-06 2.8794846e-06 1.4854581e-04 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [6.0746038e-01 4.8691229e-05 1.1338478e-01 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [2.9600162e-02 9.2799185e-10 9.3590015e-06 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [2.2905283e-01 1.7361968e-07 2.7259862e-06 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]]
#
#
# Layer 4
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[2.49099553e-01 1.08685694e-03 6.27517374e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.44526401e-01 6.98146448e-02 6.25893474e-04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.01374269e-01 4.28931962e-05 8.40617344e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [2.27104709e-01 8.03135263e-05 4.86609852e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.89932698e-01 1.13469236e-04 8.70535057e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.24154288e-01 1.52025066e-04 4.08283807e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
#
#
# Layer 5
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.03840203 0.042692   0.00733726 ... 0.         0.         0.        ]
#  [0.01265055 0.1195735  0.00650123 ... 0.         0.         0.        ]
#  [0.00636099 0.0592924  0.00478041 ... 0.         0.         0.        ]
#  ...
#  [0.03413745 0.10800253 0.00667416 ... 0.         0.         0.        ]
#  [0.03033042 0.12332498 0.04777852 ... 0.         0.         0.        ]
#  [0.04052139 0.11818473 0.01986809 ... 0.         0.         0.        ]]
#
#
# Layer 6
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.03373533 0.06678933 0.1981656  ... 0.         0.         0.        ]
#  [0.0190073  0.03220213 0.15491885 ... 0.         0.         0.        ]
#  [0.01230178 0.05172817 0.05197135 ... 0.         0.         0.        ]
#  ...
#  [0.00966674 0.00106823 0.00159211 ... 0.         0.         0.        ]
#  [0.02160253 0.00759093 0.02014102 ... 0.         0.         0.        ]
#  [0.01232014 0.00075095 0.00270869 ... 0.         0.         0.        ]]
#
#
# Layer 7
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.00463502 0.53419805 0.07465255 ... 0.         0.         0.        ]
#  [0.00138356 0.05110474 0.00132475 ... 0.         0.         0.        ]
#  [0.0020503  0.05045374 0.03779279 ... 0.         0.         0.        ]
#  ...
#  [0.02944632 0.01896778 0.0052827  ... 0.         0.         0.        ]
#  [0.10362049 0.18817344 0.06505819 ... 0.         0.         0.        ]
#  [0.04766389 0.05813608 0.02937274 ... 0.         0.         0.        ]]
#
#
# Layer 8
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.00769315 0.06012451 0.01759245 ... 0.         0.         0.        ]
#  [0.04211084 0.01145182 0.00777115 ... 0.         0.         0.        ]
#  [0.12006279 0.14195122 0.03355378 ... 0.         0.         0.        ]
#  ...
#  [0.06056374 0.00162672 0.00068223 ... 0.         0.         0.        ]
#  [0.03708984 0.01454644 0.00571251 ... 0.         0.         0.        ]
#  [0.02908084 0.00320688 0.00192949 ... 0.         0.         0.        ]]
#
#
# Layer 9
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.0638876  0.0409726  0.11271731 ... 0.         0.         0.        ]
#  [0.08934797 0.0197405  0.02850988 ... 0.         0.         0.        ]
#  [0.04978147 0.02485198 0.06447259 ... 0.         0.         0.        ]
#  ...
#  [0.00935095 0.00109427 0.00112869 ... 0.         0.         0.        ]
#  [0.03359426 0.00986531 0.01478238 ... 0.         0.         0.        ]
#  [0.00768379 0.00095038 0.00066004 ... 0.         0.         0.        ]]
#
#
# Layer 10
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.16148645 0.03832671 0.08706801 ... 0.         0.         0.        ]
#  [0.00407855 0.1657018  0.00395259 ... 0.         0.         0.        ]
#  [0.01780307 0.10859854 0.1249849  ... 0.         0.         0.        ]
#  ...
#  [0.03530228 0.28657058 0.0278152  ... 0.         0.         0.        ]
#  [0.17140618 0.02931687 0.10500532 ... 0.         0.         0.        ]
#  [0.1643743  0.07670386 0.15229283 ... 0.         0.         0.        ]]
#
#
# Layer 11
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.19911505 0.07376488 0.14892946 ... 0.         0.         0.        ]
#  [0.01742397 0.04375612 0.01634236 ... 0.         0.         0.        ]
#  [0.04695235 0.02132681 0.03470814 ... 0.         0.         0.        ]
#  ...
#  [0.022428   0.00774437 0.03071375 ... 0.         0.         0.        ]
#  [0.22482231 0.02737731 0.10748093 ... 0.         0.         0.        ]
#  [0.23919766 0.01546419 0.08674648 ... 0.         0.         0.        ]]
#
#
# Layer 12
# ['[CLS]', 'shot', ',', 'like', 'really', 'losing', 'anything', ',', 'already', 'annoying', 'without', 'anything', 'lo', '##l', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
# [[0.19171992 0.06359105 0.04037357 ... 0.         0.         0.        ]
#  [0.01436584 0.01103431 0.00365622 ... 0.         0.         0.        ]
#  [0.06426417 0.02629861 0.02089441 ... 0.         0.         0.        ]
#  ...
#  [0.02644147 0.01311998 0.01429313 ... 0.         0.         0.        ]
#  [0.15109791 0.01841962 0.04010371 ... 0.         0.         0.        ]
#  [0.14126183 0.01510762 0.02908342 ... 0.         0.         0.        ]]

# %%
'''qualitative example'''
# Define indices of examples to examine
example_indices = [0, 1, 2, 3, 4, 5, 6]

# Convert the predicted probabilities to binary labels
test_predictions = model.predict([test_input_ids, test_attention_masks])
test_binary_predictions = (np.array(test_predictions.logits, dtype=float) >= 0.5).astype(int)

# Define label names
label_names = ['happiness', 'love', 'enthusiasm', 'fun', 'surprise', 'neutral', 'sadness']

# Choose some examples to examine in more detail
for i in example_indices:
    # Get the input text and true label for the example
    input_text = df['Content'].iloc[test_index[i]]
    true_label = test_labels[i]

    # Get the predicted label for the example
    predicted_label = test_binary_predictions[i]

    # Map the predicted label indices to their names
    predicted_label_names = [label_names[j] for j, label in enumerate(predicted_label) if label == 1]

    # Print the input text, true label, and predicted label
    print("Input text:", input_text)
    print("True label:", true_label)
    print("Predicted label:", predicted_label)
# Out:
# 250/250 [==============================] - 75s 302ms/step
# Input text: shot, like really losing anything, already annoying without anything lol
# True label: [0 0 0 0 0 0 0]
# Predicted label: [0 0 0 0 0 0 0]
# Input text: live sort overthinking thing lot correctly now, spring break extended deuce week maybe even longer cannot handle isolation house, cannot blend in hang friend stupid sleep together virus barely even leave house, around parent really crippling, always make fun weight insult time point lock room never leave unless to, alone long really hard handle, starting overthink lot things. boyfriend want anymore, find someone good, many people could got reason chose really conflicted, really scared friend going get tired dealing me, stress thing time like driving insane cannot even sleep nights, sleep schedule fucked want hug mortal right straight off, tell going okay, really weak sometimes wish reassurance make this, even little bit, even much
# True label: [1 1 1 1 1 0 0]
# Predicted label: [1 1 1 1 1 0 0]
# Input text: I anxiety attack former morning like 2am. I told take drink get fuckin sleep
# True label: [0 1 0 0 1 1 0]
# Predicted label: [0 1 0 0 1 1 0]
# Input text: It unnatural interested sort thing, even young age. But st , I would trust future you, might know better now. When young, might regret hard longterm consequences, people easily take advantage consent legally recognised come people young. Sorry, got wait friend
# True label: [0 0 0 0 0 0 0]
# Predicted label: [0 0 0 0 0 0 0]
# Input text: koko !! scroll notice good example compatible certain people
# True label: [0 0 0 0 0 0 0]
# Predicted label: [0 0 0 0 0 0 0]
# Input text: online quiz dogshit opinion need quiz net decide mental health brain. person depression slwoly recognize it. start lsoign joy thing loved. start become mentally physically exhaust. sometimes eat try eat all. Sometimes care much people intend give fuck anybodys opinions. Your mind clouded every judgement move make. I also anxiety completetly mess province mind. Having anxiety depression like scared tired time. It fear failure, urge productive. It wanting friends, hate socializing. It wanting alone, want lonely. It caring nothing. It feeling everything feeling paralyzingly numb. Depression get want care anything anxiety make care every single matter hell.
# True label: [1 0 1 1 0 1 0]
# Predicted label: [1 0 1 1 0 1 0]
# Input text: Theres guy school Ive texting abd shit met like 2 hebdomad agone last Friday I hung friend house thing went pretty damn far u week school thing ok I gauge would call Tuesday stopped today I class never even approached me, say hi nothing kept walking past even fucking said excuse like I stranger. I know didnt play shit tell show isnt comparable hasnt responded ANYTHING Im inpatient I played I need know fare. Like he busy abd Im overthinking. . i bonk
# True label: [0 1 0 1 1 0 0]
# Predicted label: [0 1 0 1 1 0 0]

# %%
# Error analysis
predictions = model.predict([test_input_ids, test_attention_masks])
logits = predictions.logits
threshold = 0.5
predicted_labels = (np.array(logits, dtype=float) >= threshold).astype(int)
true_labels = test_labels
# Out:
# 250/250 [==============================] - 75s 302ms/step

# %%
errors = []
for i, (pred, true) in enumerate(zip(predicted_labels, true_labels)):
    if not np.array_equal(pred, true):
        errors.append(i)

print(f"Total errors: {len(errors)}")



# Inspect a specific error
for i in range(1000):
  error_index = errors[i]  # Change this to analyze different errors
  error_df_index = test_index[error_index]  # Get the index in the original dataframe
  print(f"Error {error_index}")
  print("Content: ", df.iloc[error_df_index]['Content'])  # Print the content of the misclassified sample
  print("True labels: ", true_labels[error_index])
  print("Predicted labels: ", predicted_labels[error_index])
  error_content = df.iloc[error_df_index]['Content']
  print(f"Content: {error_content}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Error 7
# Content:  Mel could right, I never know never say anything
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Mel could right, I never know never say anything
# Error 8
# Content:  I Have dealing low point since like feb year I like hah! It cannot get worse last year! I fine!! But day I get lower lower think lowest ever
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: I Have dealing low point since like feb year I like hah! It cannot get worse last year! I fine!! But day I get lower lower think lowest ever
# Error 9
# Content:  Not saying try cry feel like could , good card play
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Not saying try cry feel like could , good card play
# Error 14
# Content:  Nothing ruin everything waste parent money barren time blame everyone done trouble reason champion bad mood feeling like shit bringing mood
# True labels:  [0 0 0 1 1 1 0]
# Predicted labels:  [0 0 0 1 0 1 0]
# Content: Nothing ruin everything waste parent money barren time blame everyone done trouble reason champion bad mood feeling like shit bringing mood
# Error 20
# Content:  Actually every single relationship I LDR, ik sort thing feel
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Actually every single relationship I LDR, ik sort thing feel
# Error 23
# Content:  Corona affecting everyone negatively Im trusted thing get better
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Corona affecting everyone negatively Im trusted thing get better
# Error 28
# Content:  I want leave dad place. I feel like could feel better happier stay months. I see month atm, miss lot
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I want leave dad place. I feel like could feel better happier stay months. I see month atm, miss lot
# Error 29
# Content:  So, I 14..Right..and..I thought, Hey, I drink coffee every morning, Why buy energy drink
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: So, I 14..Right..and..I thought, Hey, I drink coffee every morning, Why buy energy drink
# Error 45
# Content:  You making conversation slightly pointless anything say positive get shot negativity life meaningless stuff. Sooo difficult say anything make feel better really trying sound mean
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: You making conversation slightly pointless anything say positive get shot negativity life meaningless stuff. Sooo difficult say anything make feel better really trying sound mean
# Error 46
# Content:  Marshmelly find something distracting far emotion experience? Maybe listening story podcasts refer look?
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Marshmelly find something distracting far emotion experience? Maybe listening story podcasts refer look?
# Error 49
# Content:  I feel like I one kept relationship together I giving
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I feel like I one kept relationship together I giving
# Error 52
# Content:  I drunk slept like 6 hour 2 I hangover headache quick tip Care
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I drunk slept like 6 hour 2 I hangover headache quick tip Care
# Error 55
# Content:  I diet good well exercise tracking I returned bad habits, feel lazy unproductive cannot workout I used
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 1 0 0 0 0]
# Content: I diet good well exercise tracking I returned bad habits, feel lazy unproductive cannot workout I used
# Error 61
# Content:  I used hate too. I still extent. But possible learn accept yourself, love spite flaws.
# True labels:  [0 0 1 1 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: I used hate too. I still extent. But possible learn accept yourself, love spite flaws.
# Error 62
# Content:  But matter do, all the same you, one take you, even end
# True labels:  [1 0 0 0 0 0 1]
# Predicted labels:  [1 0 0 1 0 0 1]
# Content: But matter do, all the same you, one take you, even end
# Error 84
# Content:  Bad I I study tomorrow turned I analyse day turned I study tonight turned I wake exam study bit ultimately flex Fuck
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Bad I I study tomorrow turned I analyse day turned I study tonight turned I wake exam study bit ultimately flex Fuck
# Error 92
# Content:  It like, I changed anything anything else I keep getting low mark
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: It like, I changed anything anything else I keep getting low mark
# Error 97
# Content:  I give care support people need it, sometimes, one reassure everything alright
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I give care support people need it, sometimes, one reassure everything alright
# Error 100
# Content:  If I see 30yo man claiming genderfluid walk bathroom future daughter amount SJW feminist leftism going stop beating as
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: If I see 30yo man claiming genderfluid walk bathroom future daughter amount SJW feminist leftism going stop beating as
# Error 130
# Content:  The fact die end reminder live life fullest
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: The fact die end reminder live life fullest
# Error 135
# Content:  need help, partner able spend time together talk together life changing stage know organize social life
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: need help, partner able spend time together talk together life changing stage know organize social life
# Error 147
# Content:  honestly feel like breaking shit right now, really hard quit smoking think aboout right
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [1 0 0 0 0 0 0]
# Content: honestly feel like breaking shit right now, really hard quit smoking think aboout right
# Error 159
# Content:  So huge difference fucking around broke weapon got pissed stabbed
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: So huge difference fucking around broke weapon got pissed stabbed
# Error 171
# Content:  Care Hey. I need friend talk long time. I open people right now. I want talk long time , After I get know other, I want talk seriously problem. I really need care it. If I solve it..I going end me...I think I already dead, like life. help me. plz..... I need liar, pretense, short time. I wish I found good person. I want talk pm people say,dm I dm them.but conversation I Hey. If talk, say dm I need puppetry liar. I really need talk honestly seriously .... fake... I want talk long time
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Care Hey. I need friend talk long time. I open people right now. I want talk long time , After I get know other, I want talk seriously problem. I really need care it. If I solve it..I going end me...I think I already dead, like life. help me. plz..... I need liar, pretense, short time. I wish I found good person. I want talk pm people say,dm I dm them.but conversation I Hey. If talk, say dm I need puppetry liar. I really need talk honestly seriously .... fake... I want talk long time
# Error 180
# Content:  I called one friend mean friend mean started going telling much I sucked
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I called one friend mean friend mean started going telling much I sucked
# Error 184
# Content:  Yeah sorry I asshole I want tell I would choose others
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Yeah sorry I asshole I want tell I would choose others
# Error 186
# Content:  I tired lonely time person I talk I wait day I feel like I needy everything suck
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 1 1 0 0 0]
# Content: I tired lonely time person I talk I wait day I feel like I needy everything suck
# Error 192
# Content:  Trust come sentence ice cream. So give family relationship time.
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Trust come sentence ice cream. So give family relationship time.
# Error 194
# Content:  true, want make obvious someting slowly stop messaging reacting it, obviously notice noticeable
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: true, want make obvious someting slowly stop messaging reacting it, obviously notice noticeable
# Error 196
# Content:  I left school became homeschooled twice span two year gotten worse
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 1 0 0]
# Content: I left school became homeschooled twice span two year gotten worse
# Error 213
# Content:  I keep feeling urge die I know wrong always backup plan
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I keep feeling urge die I know wrong always backup plan
# Error 216
# Content:  If Im forgotten whats point living, since nobody care Ive done Ive accomplished,
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: If Im forgotten whats point living, since nobody care Ive done Ive accomplished,
# Error 225
# Content:  This conversation really emotionally help much, appear petering out. So unless someone something say... I going go read book likely appear server likely many months. This meant jab mean, I likely courage reach help. Feel free someone pick back up, I hold breath. Goodbye now, thanks attempt.
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: This conversation really emotionally help much, appear petering out. So unless someone something say... I going go read book likely appear server likely many months. This meant jab mean, I likely courage reach help. Feel free someone pick back up, I hold breath. Goodbye now, thanks attempt.
# Error 230
# Content:  He supposed pick tonight dinner parent I worried I ruin everything I upset situation
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: He supposed pick tonight dinner parent I worried I ruin everything I upset situation
# Error 235
# Content:  I wrong person ask. Again, I focused romantic stuff. I need experience romantic life within year two. I see making past unless I act. I already experience unwanted left out. One despise alive.
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 1]
# Content: I wrong person ask. Again, I focused romantic stuff. I need experience romantic life within year two. I see making past unless I act. I already experience unwanted left out. One despise alive.
# Error 249
# Content:  I mean I talk I think legal talk suicide disapperance soo
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I mean I talk I think legal talk suicide disapperance soo
# Error 260
# Content:  Iodin it. Lifting weightiness. Tidying haunted flat. Going walks. Staying away alcohol etc
# True labels:  [1 0 0 0 0 0 1]
# Predicted labels:  [1 0 0 0 1 0 1]
# Content: Iodin it. Lifting weightiness. Tidying haunted flat. Going walks. Staying away alcohol etc
# Error 272
# Content:  smh give really great advice. might dm time issue honest
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: smh give really great advice. might dm time issue honest
# Error 278
# Content:  I might actually work playlist. I working week really fun me.
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I might actually work playlist. I working week really fun me.
# Error 280
# Content:  And not, important thing me, always
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: And not, important thing me, always
# Error 291
# Content:  I kind want grab 226 thats next shoot self
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I kind want grab 226 thats next shoot self
# Error 292
# Content:  You know stuff already, girlfriend leaving read responding much even though talked week would think would excited talk, noooo! say might busy, everytime I hopped messanger talk friend either active minute ago, I know I fucked up, I know I awkward, want talk would understand know put
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: You know stuff already, girlfriend leaving read responding much even though talked week would think would excited talk, noooo! say might busy, everytime I hopped messanger talk friend either active minute ago, I know I fucked up, I know I awkward, want talk would understand know put
# Error 300
# Content:  Care 1 depression hitting hard I want one person talk
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care 1 depression hitting hard I want one person talk
# Error 311
# Content:  oh realised. They Are going oit get crossfaded. So going go smoke weed. Nice. Woohoo. Cannot wait
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: oh realised. They Are going oit get crossfaded. So going go smoke weed. Nice. Woohoo. Cannot wait
# Error 314
# Content:  Everything hurt hahah lmao ready give worthless hahaha
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Everything hurt hahah lmao ready give worthless hahaha
# Error 317
# Content:  feel pretend happy around everyone reality want outcry
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: feel pretend happy around everyone reality want outcry
# Error 319
# Content:  If teach x person good way, mean would maybe treat same.
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: If teach x person good way, mean would maybe treat same.
# Error 320
# Content:  Bye guys. I leaving server mental upset get much handle
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Bye guys. I leaving server mental upset get much handle
# Error 321
# Content:  brother always either drunk high, friend fucking. UGH
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: brother always either drunk high, friend fucking. UGH
# Error 330
# Content:  Care yelled hour half cry feeling shamefaced, I receive room door taken 1 failed English exam mom accusing lying studying
# True labels:  [0 0 0 1 0 0 1]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Care yelled hour half cry feeling shamefaced, I receive room door taken 1 failed English exam mom accusing lying studying
# Error 341
# Content:  honestly feel like nothing get better anymore, hope left come back end way loop suffering never get better get worse road go always told going end somehow hard believe know wake morning anymore Care
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: honestly feel like nothing get better anymore, hope left come back end way loop suffering never get better get worse road go always told going end somehow hard believe know wake morning anymore Care
# Error 342
# Content:  I know aunt least know mom really like, I still sure do. I think best I leave good, even I leave everyone
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I know aunt least know mom really like, I still sure do. I think best I leave good, even I leave everyone
# Error 355
# Content:  Almost becoming mute, struggle use voice. I know I never talk anymore gerdacid reflux getting worse.
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Almost becoming mute, struggle use voice. I know I never talk anymore gerdacid reflux getting worse.
# Error 380
# Content:  give anxiety I want express amazing is, much mean I love much like
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 1 0]
# Content: give anxiety I want express amazing is, much mean I love much like
# Error 387
# Content:  After slap, freaking ignore her. And request mum unless realizes fault
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: After slap, freaking ignore her. And request mum unless realizes fault
# Error 393
# Content:  would truly moved thus negative emotion towards situation
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: would truly moved thus negative emotion towards situation
# Error 394
# Content:  ah it,we fun bit I got sick mad every little detail
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: ah it,we fun bit I got sick mad every little detail
# Error 395
# Content:  I know I let others opinion effect I obliterate I right going full as complete rejection mode
# True labels:  [0 0 1 1 1 0 1]
# Predicted labels:  [0 0 1 1 1 0 0]
# Content: I know I let others opinion effect I obliterate I right going full as complete rejection mode
# Error 397
# Content:  turtleoldacc yeah I kind getting state Iodin distance friend I honestly remember think I joke group annoying one peice shit need ditch
# True labels:  [0 0 1 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: turtleoldacc yeah I kind getting state Iodin distance friend I honestly remember think I joke group annoying one peice shit need ditch
# Error 399
# Content:  Care So like sitting class right friend taking dig thing make feel self conscious know do. pretty sure like pretend like feel bad everytime around them. make feel embarrassed one else make feel way. tried mentioning ignored it, still include inviting party n stuff feel fake
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care So like sitting class right friend taking dig thing make feel self conscious know do. pretty sure like pretend like feel bad everytime around them. make feel embarrassed one else make feel way. tried mentioning ignored it, still include inviting party n stuff feel fake
# Error 404
# Content:  I feel extremely narcissistic I cannot really peace create destruction I feel talking thing make advice viable valid, I tend continue I moment rush good
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I feel extremely narcissistic I cannot really peace create destruction I feel talking thing make advice viable valid, I tend continue I moment rush good
# Error 405
# Content:  Omg mood shift I thinking I really am, I somebody put face front everybody try always cheerful energetic I alone certain people I break cannot function Its started get harder cheerful lately I realizing I want people sake I know much I I know I want keep
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 1 0 0 0 0]
# Content: Omg mood shift I thinking I really am, I somebody put face front everybody try always cheerful energetic I alone certain people I break cannot function Its started get harder cheerful lately I realizing I want people sake I know much I I know I want keep
# Error 406
# Content:  get wrong, great parents. I shitty child 1 sincerely experience love
# True labels:  [0 0 0 1 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: get wrong, great parents. I shitty child 1 sincerely experience love
# Error 415
# Content:  I feel powerless making friends, always seems I make friend world decides I friend
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I feel powerless making friends, always seems I make friend world decides I friend
# Error 444
# Content:  mito try complete small task day finger lazy. The sense skill go along way. And so set goal try complete
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 1 0 0 0 0]
# Content: mito try complete small task day finger lazy. The sense skill go along way. And so set goal try complete
# Error 464
# Content:  Care need advice , kind urgent, understand supposed really ask suicide stuff. dealt lot stuff nervous able help. cannot get advice maybe maybe reassurance part. freaking tf
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care need advice , kind urgent, understand supposed really ask suicide stuff. dealt lot stuff nervous able help. cannot get advice maybe maybe reassurance part. freaking tf
# Error 465
# Content:  Deleted User lonely make friend first start ready try relationship
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Deleted User lonely make friend first start ready try relationship
# Error 466
# Content:  Yeah hating make worse I consistently reminded I failed grow apathy towards method I know would work.
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Yeah hating make worse I consistently reminded I failed grow apathy towards method I know would work.
# Error 468
# Content:  Corona affecting everyone negatively Im certain thing get better
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Corona affecting everyone negatively Im certain thing get better
# Error 473
# Content:  Its dumb. She fucked shit stressful fuck yet thing want right talk
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Its dumb. She fucked shit stressful fuck yet thing want right talk
# Error 477
# Content:  know new verbalize lots, needed help. today taken infirmary severe pain chest learned anxiety severe effected ticker caused pain struggling breathing. never good calming panic onrush never know exactly do. usually reach people ask talk random stuff distract mind, everyone kind cut schooling ended. felt extremely alone scared future hold condition heart.
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: know new verbalize lots, needed help. today taken infirmary severe pain chest learned anxiety severe effected ticker caused pain struggling breathing. never good calming panic onrush never know exactly do. usually reach people ask talk random stuff distract mind, everyone kind cut schooling ended. felt extremely alone scared future hold condition heart.
# Error 480
# Content:  hey man school keep making phone go stop Deleted User
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: hey man school keep making phone go stop Deleted User
# Error 488
# Content:  So um ex may know keep trying dm follow keep stalking social medium I know anymore honest stop EVER say maybe want apologize always say yet also I told leave alone long time ago yet respect I idea right Care
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: So um ex may know keep trying dm follow keep stalking social medium I know anymore honest stop EVER say maybe want apologize always say yet also I told leave alone long time ago yet respect I idea right Care
# Error 495
# Content:  know do? try deal emotion instead taking everyone else. unrivaled else hour angle deal emotion problem choose
# True labels:  [0 0 1 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: know do? try deal emotion instead taking everyone else. unrivaled else hour angle deal emotion problem choose
# Error 501
# Content:  well mum yelled me, told like kept it, thing
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: well mum yelled me, told like kept it, thing
# Error 502
# Content:  I considered following running away, standing parents, call cps, lightly think killing mom thing got point
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I considered following running away, standing parents, call cps, lightly think killing mom thing got point
# Error 504
# Content:  I understand do. I suicidal myself. I want refuse lot live I even know. Why waste it? Not saying would be, view help me.
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 1]
# Content: I understand do. I suicidal myself. I want refuse lot live I even know. Why waste it? Not saying would be, view help me.
# Error 506
# Content:  listen. treating mental illness exhausting, nothing living even exhausting.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: listen. treating mental illness exhausting, nothing living even exhausting.
# Error 521
# Content:  Care feeling like dog like per say know alot stresspain attack, depression alot
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care feeling like dog like per say know alot stresspain attack, depression alot
# Error 530
# Content:  relate lot that, actually. isolation friend family. parent always you...
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: relate lot that, actually. isolation friend family. parent always you...
# Error 537
# Content:  Ashuraamy fucking body bruise bullshitery I want wake feel pain
# True labels:  [0 1 0 1 0 0 1]
# Predicted labels:  [0 1 0 0 0 0 1]
# Content: Ashuraamy fucking body bruise bullshitery I want wake feel pain
# Error 542
# Content:  day ago told keep talking acne getting bursting vociferation
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: day ago told keep talking acne getting bursting vociferation
# Error 557
# Content:  sat talked still not. .. i guess trust know feel corresponding best agency tell feel get angry tell also always told moment start thinking breaking someone relationship already done already talked still feel uneasy gem state say try tell watch response guess? sorry place take must
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: sat talked still not. .. i guess trust know feel corresponding best agency tell feel get angry tell also always told moment start thinking breaking someone relationship already done already talked still feel uneasy gem state say try tell watch response guess? sorry place take must
# Error 568
# Content:  Deleted User Hey listen, It fault, I feed attention If I hate someone I talk, I meet, I block
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Deleted User Hey listen, It fault, I feed attention If I hate someone I talk, I meet, I block
# Error 574
# Content:  I understand could busy something, enough time look story texts, enough time ask I feeling
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I understand could busy something, enough time look story texts, enough time ask I feeling
# Error 583
# Content:  So girlfriend running away house becuause problem family going travel another state know feel sad becuause girlfriend feel like cannot anything help Just give advice
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: So girlfriend running away house becuause problem family going travel another state know feel sad becuause girlfriend feel like cannot anything help Just give advice
# Error 584
# Content:  That back mind right though, mostly feeling like fuckin moron falling asleep mid shift.
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 1 0 1 0 0 0]
# Content: That back mind right though, mostly feeling like fuckin moron falling asleep mid shift.
# Error 588
# Content:  I also feel nausous morning lately, I sure part anxiety well.
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 1 0 0]
# Content: I also feel nausous morning lately, I sure part anxiety well.
# Error 591
# Content:  life never ending cycle going work, trying find effort fuck besides drug smoke whenever home
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 1 0 0]
# Content: life never ending cycle going work, trying find effort fuck besides drug smoke whenever home
# Error 592
# Content:  Razor I know I stuff I like I have intercourse I catch some z's I like I want
# True labels:  [0 1 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 1 0 0]
# Content: Razor I know I stuff I like I have intercourse I catch some z's I like I want
# Error 594
# Content:  I think anything wrong want throw away I mean hey I let destroy friendship
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I think anything wrong want throw away I mean hey I let destroy friendship
# Error 597
# Content:  I get mean busying kind distract also prove wrong time
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I get mean busying kind distract also prove wrong time
# Error 604
# Content:  My mum called earlier. Asked post I shared country suicide hotline pretty useless
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: My mum called earlier. Asked post I shared country suicide hotline pretty useless
# Error 612
# Content:  cannot let go someone literally life life anymore? complicated know
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: cannot let go someone literally life life anymore? complicated know
# Error 613
# Content:  I know want cheer cut
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I know want cheer cut
# Error 622
# Content:  yea. dad kind transphobic brothers, though part LGBT community itself, exactly kind people I want come to...
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: yea. dad kind transphobic brothers, though part LGBT community itself, exactly kind people I want come to...
# Error 638
# Content:  You might technique main idea stop thought cause panic like thinking youll stop breathing
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: You might technique main idea stop thought cause panic like thinking youll stop breathing
# Error 640
# Content:  I playlist cunning little friend song used make really happy guess fuck what. I keep thinking want punch fucking brass I want good stable friendship
# True labels:  [0 1 0 1 0 0 0]
# Predicted labels:  [0 1 1 1 0 0 0]
# Content: I playlist cunning little friend song used make really happy guess fuck what. I keep thinking want punch fucking brass I want good stable friendship
# Error 652
# Content:  could lucid dreaming knife stomach because... If lucid dream think knife shit happens seems real saved memory
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: could lucid dreaming knife stomach because... If lucid dream think knife shit happens seems real saved memory
# Error 664
# Content:  bother me. reason taking tired annoying get down mess. people always offer support, ne'er find motivation get advice head
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 1 1 0]
# Content: bother me. reason taking tired annoying get down mess. people always offer support, ne'er find motivation get advice head
# Error 665
# Content:  All holding back escaping camp, small piece rope tied one legs. As man gazed upon elephants, completely confused elephant didnt use strength break rope escape camp. They could easily done so, instead, didnt try all. Curious wanting know answer, asked trainer nearby elephant standing never tried escape.
# True labels:  [0 0 0 1 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: All holding back escaping camp, small piece rope tied one legs. As man gazed upon elephants, completely confused elephant didnt use strength break rope escape camp. They could easily done so, instead, didnt try all. Curious wanting know answer, asked trainer nearby elephant standing never tried escape.
# Error 668
# Content:  I staying roomates impossible find place alone LA. I bad credit, I social anxiety. I cannot live
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: I staying roomates impossible find place alone LA. I bad credit, I social anxiety. I cannot live
# Error 674
# Content:  Message sent JAY deleted support Care twohearts I sick this. I get bullied I part LGBTQ, sick bullied, sick called f word every day
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Message sent JAY deleted support Care twohearts I sick this. I get bullied I part LGBTQ, sick bullied, sick called f word every day
# Error 680
# Content:  get mad. think good enough reason like that.
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: get mad. think good enough reason like that.
# Error 681
# Content:  yo know know even gf cheated best friend got back togheter trying friend cool inside dying
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: yo know know even gf cheated best friend got back togheter trying friend cool inside dying
# Error 689
# Content:  Care I call for someone talk I feel someway depressed suicidal sry double ping
# True labels:  [0 0 1 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 1]
# Content: Care I call for someone talk I feel someway depressed suicidal sry double ping
# Error 696
# Content:  I feel like someone trying pull nerve body bare hand
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I feel like someone trying pull nerve body bare hand
# Error 706
# Content:  Care I suffering panic attack honestly I ready give
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 1 0 1 1 0]
# Content: Care I suffering panic attack honestly I ready give
# Error 720
# Content:  starting really feel like one respect opinion house
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: starting really feel like one respect opinion house
# Error 722
# Content:  Thanks change anything I said I want skip shitty hard life I cannot change anything try best I know I fail like everytime I fucking try
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Thanks change anything I said I want skip shitty hard life I cannot change anything try best I know I fail like everytime I fucking try
# Error 736
# Content:  Ok dog passed away feel fucking empty now. That dog one loyal pal would hardest times. He would sit lay beside me. Everytime go home would come greet me, even bad mood turned good one. I Am scared find another dog like him, wish time spend him... Right asking die good person almost sacrificed time people? And come home hear passed away. This make mad time sad, feel like living life without pal would hard worth living for. He like true friend imagined never had... Wish see one day time right...
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Ok dog passed away feel fucking empty now. That dog one loyal pal would hardest times. He would sit lay beside me. Everytime go home would come greet me, even bad mood turned good one. I Am scared find another dog like him, wish time spend him... Right asking die good person almost sacrificed time people? And come home hear passed away. This make mad time sad, feel like living life without pal would hard worth living for. He like true friend imagined never had... Wish see one day time right...
# Error 742
# Content:  It help. I attest 20 year therapy help save life make life awesome too. Sure I still struggle
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: It help. I attest 20 year therapy help save life make life awesome too. Sure I still struggle
# Error 746
# Content:  use hate then, since life hate you, hate back, life hurt you, hurt back, life kill you, walk start back hate.
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: use hate then, since life hate you, hate back, life hurt you, hurt back, life kill you, walk start back hate.
# Error 757
# Content:  Now I needy pathetic rely people validation feel like whole human
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Now I needy pathetic rely people validation feel like whole human
# Error 758
# Content:  domt put pressure anyone carw becaise deserve hatred anf pain thd end
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: domt put pressure anyone carw becaise deserve hatred anf pain thd end
# Error 760
# Content:  jus make sure keep bottled in, able talk loved one get thought feel comfortable write express way, find distraction
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: jus make sure keep bottled in, able talk loved one get thought feel comfortable write express way, find distraction
# Error 771
# Content:  It scary thought maybe I hurted fault
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: It scary thought maybe I hurted fault
# Error 778
# Content:  anyways, right place dicsussion since Fizzy apperently left, going go back shadow
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: anyways, right place dicsussion since Fizzy apperently left, going go back shadow
# Error 789
# Content:  like it? think thinking ask that?
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: like it? think thinking ask that?
# Error 795
# Content:  I watching super neat video, I trying favor trying help
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I watching super neat video, I trying favor trying help
# Error 796
# Content:  It cause panic attack like 230 morning I star door think something coming something going kill
# True labels:  [0 1 0 1 0 0 1]
# Predicted labels:  [0 1 0 0 0 0 1]
# Content: It cause panic attack like 230 morning I star door think something coming something going kill
# Error 801
# Content:  know stupid vent about, oh well. teacher barely posted work beginning quarantine thought going back school, know know overworking u like crazy. math teacher assigns like 56 page math every day oly day it. like class well. starting upset much work every day still working 1011pm. ridiculous. get relax time stressing out.
# True labels:  [0 1 0 1 0 0 0]
# Predicted labels:  [0 1 0 0 0 0 0]
# Content: know stupid vent about, oh well. teacher barely posted work beginning quarantine thought going back school, know know overworking u like crazy. math teacher assigns like 56 page math every day oly day it. like class well. starting upset much work every day still working 1011pm. ridiculous. get relax time stressing out.
# Error 813
# Content:  need help, wanting die name? give name well, name, parent know this? no.. well maybe get parent know hang
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: need help, wanting die name? give name well, name, parent know this? no.. well maybe get parent know hang
# Error 820
# Content:  im idr called, believe lot stuff sorta higher power dont believe whole god scenario
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: im idr called, believe lot stuff sorta higher power dont believe whole god scenario
# Error 826
# Content:  See even hate true know why? Because true fun
# True labels:  [0 0 0 1 1 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: See even hate true know why? Because true fun
# Error 832
# Content:  well, try thinking way, think superior instead, since ability think thing deeply
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: well, try thinking way, think superior instead, since ability think thing deeply
# Error 847
# Content:  Care brother moved back family I afraid planning killing mom
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care brother moved back family I afraid planning killing mom
# Error 850
# Content:  tough, maybe ask it? enough!! litty cheat
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: tough, maybe ask it? enough!! litty cheat
# Error 868
# Content:  worry mom might overhearing conversation cause extra anxiety
# True labels:  [0 0 0 1 1 1 0]
# Predicted labels:  [0 0 0 0 1 1 0]
# Content: worry mom might overhearing conversation cause extra anxiety
# Error 883
# Content:  yep thats insightful, thank you. ill keep mind try steer clear bad unhealthy coping mechanisms. hope learn overcome coping mechanisms.
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: yep thats insightful, thank you. ill keep mind try steer clear bad unhealthy coping mechanisms. hope learn overcome coping mechanisms.
# Error 891
# Content:  noobie boobie! well. If I you, I would pretty much slap shit her.
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: noobie boobie! well. If I you, I would pretty much slap shit her.
# Error 892
# Content:  I wanted escape, I made excuse want anything, many years, I grew hatred nothing...what point trying maintain revenge I create type happiness, forgive them, I cannot rely everyone I cannot blame anyone happened
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I wanted escape, I made excuse want anything, many years, I grew hatred nothing...what point trying maintain revenge I create type happiness, forgive them, I cannot rely everyone I cannot blame anyone happened
# Error 893
# Content:  back middleschool I pretty afraid talking girls,so I afraid talking girl,it I find girl attractive
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: back middleschool I pretty afraid talking girls,so I afraid talking girl,it I find girl attractive
# Error 896
# Content:  Im sorry, I dont know else say keep trying exercise. Youll see results. I started working similar 2 week ago started exhaust healthy I already see onward motion. Im sure itll
# True labels:  [1 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 1 0 0]
# Content: Im sorry, I dont know else say keep trying exercise. Youll see results. I started working similar 2 week ago started exhaust healthy I already see onward motion. Im sure itll
# Error 901
# Content:  Care lot going friend keep talking le le make sad edits stuff like that. geniunely worried health know ask ok etc. need advice.
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Care lot going friend keep talking le le make sad edits stuff like that. geniunely worried health know ask ok etc. need advice.
# Error 903
# Content:  I changed name I feel better sad name sad name
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I changed name I feel better sad name sad name
# Error 910
# Content:  I know I mess much more, maybe I able learn
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I know I mess much more, maybe I able learn
# Error 911
# Content:  Yeah I know Deleted User upsetting ya know. Like I know I get I fine I get good amount blame would go counselor
# True labels:  [0 0 0 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Yeah I know Deleted User upsetting ya know. Like I know I get I fine I get good amount blame would go counselor
# Error 930
# Content:  Care feel like I verge anxiety attack maybe one I need talk someone I experience same I something bad gunna come about
# True labels:  [0 0 0 1 1 1 0]
# Predicted labels:  [0 0 0 0 1 1 0]
# Content: Care feel like I verge anxiety attack maybe one I need talk someone I experience same I something bad gunna come about
# Error 945
# Content:  st okay go Fucking anyone like that. Try control okay normal might new pretty normal. Be cool. If go sex every urge make thirsty random guy cool. pleasure end sex someone.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: st okay go Fucking anyone like that. Try control okay normal might new pretty normal. Be cool. If go sex every urge make thirsty random guy cool. pleasure end sex someone.
# Error 955
# Content:  need making least 300 month. easily le half hour working right now. really want well, need full amount earning. taking day would hurt bad,
# True labels:  [0 0 0 0 0 1 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: need making least 300 month. easily le half hour working right now. really want well, need full amount earning. taking day would hurt bad,
# Error 995
# Content:  She said tell anything even would mind doubt want hear friend upset fact got gf feel like going abandoned payed attention to. Especially since first relationship? Not greatest thing hear
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: She said tell anything even would mind doubt want hear friend upset fact got gf feel like going abandoned payed attention to. Especially since first relationship? Not greatest thing hear
# Error 1010
# Content:  Yeah well got tired lonely Working it, Working me, true easy take time ik right thing get better better
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Yeah well got tired lonely Working it, Working me, true easy take time ik right thing get better better
# Error 1011
# Content:  Lucifer okay eat, count content food eat? Also sorry responding slow work
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Lucifer okay eat, count content food eat? Also sorry responding slow work
# Error 1036
# Content:  well adult likely find happiness, know family
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: well adult likely find happiness, know family
# Error 1040
# Content:  I would suggest stretching maybe even go professional massage explain problem possibly caused first occurred long for, going doctor. Sadly alot doc interested treating symptom rather actual issues, going something normal back pain, risk getting pain med
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I would suggest stretching maybe even go professional massage explain problem possibly caused first occurred long for, going doctor. Sadly alot doc interested treating symptom rather actual issues, going something normal back pain, risk getting pain med
# Error 1047
# Content:  originally cry really hard got progressively worse eventually hyperventilating, vision going dark blurry, could walk due disorentation sheer panic, face hand went stiff, mouth barely able move, took like minute get word mom, skin tingling
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 1 0 1 0 0 0]
# Content: originally cry really hard got progressively worse eventually hyperventilating, vision going dark blurry, could walk due disorentation sheer panic, face hand went stiff, mouth barely able move, took like minute get word mom, skin tingling
# Error 1064
# Content:  prob start, would start making question many thing future, possibly guilt tripping
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: prob start, would start making question many thing future, possibly guilt tripping
# Error 1077
# Content:  thought mine someone el got bad thought bad thought like cutting anything
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: thought mine someone el got bad thought bad thought like cutting anything
# Error 1079
# Content:  I know anymore, life mess keep have intercourse everything lie make feel better myself. emotion might seem fine outside inside verge breaking. one know going everyone hate everyone mock deserve anything have. thing got lie made acquaintance would done anything keep left ever so since mental state crumbled slowly think vanishing face planet. try hide emotion show feel like ill treated differently hate lie
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: I know anymore, life mess keep have intercourse everything lie make feel better myself. emotion might seem fine outside inside verge breaking. one know going everyone hate everyone mock deserve anything have. thing got lie made acquaintance would done anything keep left ever so since mental state crumbled slowly think vanishing face planet. try hide emotion show feel like ill treated differently hate lie
# Error 1099
# Content:  going fauly whem get fucking car crash dumbass drunk friend
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: going fauly whem get fucking car crash dumbass drunk friend
# Error 1101
# Content:  It really suck know meant one thing take another way sdjnfkdsfnd
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: It really suck know meant one thing take another way sdjnfkdsfnd
# Error 1117
# Content:  push away dude...you never know feel maybe gave chance
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: push away dude...you never know feel maybe gave chance
# Error 1129
# Content:  Care sorry ping haveing panic attack really bad
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care sorry ping haveing panic attack really bad
# Error 1130
# Content:  I checking I rest properly. And I worried I might weakness lungs. Might dice young.
# True labels:  [1 0 0 1 0 0 1]
# Predicted labels:  [1 0 0 1 0 0 0]
# Content: I checking I rest properly. And I worried I might weakness lungs. Might dice young.
# Error 1131
# ...
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 1 1 0 0 1]
# Content: Good night all? I couple day suffering depression, anxiety even left me, I lie try look opportunities. I living alone, father died year ago mother fell deep depression care relatives, however much prejudice family condition I preferred run away everything. My best friend scammed three week ago I run money practically, currently I barely enough rent food, guy I talking ... He ran away, someone else. When I around 1516 year old I go psychologist, I always suicidal thought depressive tendencies, day nothing happens I feel life go out, awake wanting everything end, I dream it, I sleep Thinking it, I spend day thinking it. someone dm chat while? He first person I talk haha day
# Error 5826
# Content:  got fat shamed family even though eaten day today yesterday
# True labels:  [1 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: got fat shamed family even though eaten day today yesterday
# Error 5831
# Content:  I miss him, I seen whole thing stressing out.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I miss him, I seen whole thing stressing out.
# Error 5842
# Content:  Life seriously incredibly painful easy way. Sometimes get urge give stop trying hard, harder others I get that, many amazing opportunity future know yet, might think right now, happen. You find peace, take time. If look adversity face say fuck much better off. Do give yet, worth battle man.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Life seriously incredibly painful easy way. Sometimes get urge give stop trying hard, harder others I get that, many amazing opportunity future know yet, might think right now, happen. You find peace, take time. If look adversity face say fuck much better off. Do give yet, worth battle man.
# Error 5848
# Content:  literally put food soda looking drank started laugh felt sick texture sensitivity
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: literally put food soda looking drank started laugh felt sick texture sensitivity
# Error 5850
# Content:  keep getting worse. starting become violent towards people whenever even reason starting hate one love. like either constantly sad incessantly mad, either way really turn horrible person really need around others. every time try change sake others seem refuse to, cannot. really want point hurting stop hurting others along myself. inactive lot lately fear hurting someone maintenance about, lot people server mean world scared hurting others.
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: keep getting worse. starting become violent towards people whenever even reason starting hate one love. like either constantly sad incessantly mad, either way really turn horrible person really need around others. every time try change sake others seem refuse to, cannot. really want point hurting stop hurting others along myself. inactive lot lately fear hurting someone maintenance about, lot people server mean world scared hurting others.
# Error 5851
# Content:  might little depressed, try act calm possible speaking
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: might little depressed, try act calm possible speaking
# Error 5867
# Content:  Play game forget loneliness man I play game whole day
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Play game forget loneliness man I play game whole day
# Error 5882
# Content:  listen music time. usually enjoy music relate to.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: listen music time. usually enjoy music relate to.
# Error 5883
# Content:  Id feel bad help time, Im really low hopeless nice lol, Id love able help thats amazing
# True labels:  [0 0 0 1 0 0 1]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Id feel bad help time, Im really low hopeless nice lol, Id love able help thats amazing
# Error 5892
# Content:  I se xt older guys, watch bad shit , fap, etc part along come used, hated on, getting connected people
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I se xt older guys, watch bad shit , fap, etc part along come used, hated on, getting connected people
# Error 5900
# Content:  Care I allot paranoia I house I suffer siezures. Any advice I curb bit comfortable?
# True labels:  [0 0 1 1 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Care I allot paranoia I house I suffer siezures. Any advice I curb bit comfortable?
# Error 5905
# Content:  report police violating property right threatening arm
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 0 0 1 0]
# Content: report police violating property right threatening arm
# Error 5906
# Content:  worry mom might overhearing conversation cause extra anxiousness
# True labels:  [0 0 0 1 1 1 0]
# Predicted labels:  [0 0 0 0 1 1 0]
# Content: worry mom might overhearing conversation cause extra anxiousness
# Error 5911
# Content:  know try start thinking ill get back depressive state
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: know try start thinking ill get back depressive state
# Error 5915
# Content:  I abused I really young, I opened it, listened began using undertone make joke poke fun
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I abused I really young, I opened it, listened began using undertone make joke poke fun
# Error 5918
# Content:  He job supermarket, I cannot believe worked long
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: He job supermarket, I cannot believe worked long
# Error 5919
# Content:  hate ever wanted accept me. tried hard sake, everything done improve myself, even get bit approval her, hate much, hurt much. clingy towards everyone parent even care insecure, parent love anyone else love
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: hate ever wanted accept me. tried hard sake, everything done improve myself, even get bit approval her, hate much, hurt much. clingy towards everyone parent even care insecure, parent love anyone else love
# Error 5932
# Content:  many people lost life time choice matter, selfish use option still ate alive breathing
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 1]
# Content: many people lost life time choice matter, selfish use option still ate alive breathing
# Error 5933
# Content:  yeah know, lot together go person I know going find anybody else like
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: yeah know, lot together go person I know going find anybody else like
# Error 5944
# Content:  would, go sleep presently, want leave hanging
# True labels:  [0 1 0 1 0 0 0]
# Predicted labels:  [0 1 0 0 0 0 0]
# Content: would, go sleep presently, want leave hanging
# Error 5949
# Content:  A reasons. 1. If wanted help would gone instead here, every one sap money tell hopeless every single visit. Every single doctortherapist counselor. I tried 3 year
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 1]
# Content: A reasons. 1. If wanted help would gone instead here, every one sap money tell hopeless every single visit. Every single doctortherapist counselor. I tried 3 year
# Error 5957
# Content:  If anyone comfortable talking depression thought suicide available long talk please DM me, I leave
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: If anyone comfortable talking depression thought suicide available long talk please DM me, I leave
# Error 5959
# Content:  negative way bull shit. Be happy let anyone control
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: negative way bull shit. Be happy let anyone control
# Error 5965
# Content:  feel like I everything I everyday, also feel I nothing
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: feel like I everything I everyday, also feel I nothing
# Error 5985
# Content:  It different campus I would going schooling I wanted call either follow ask I would know I got
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: It different campus I would going schooling I wanted call either follow ask I would know I got
# Error 6017
# Content:  And I care? I would feel drop sadness empathy Unity would alive
# True labels:  [0 0 0 1 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: And I care? I would feel drop sadness empathy Unity would alive
# Error 6018
# Content:  thing sister get extrem feeling watched
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: thing sister get extrem feeling watched
# Error 6021
# Content:  How this, ask think person. Cuz said wishing show cared true, might feel suppressed cornered.
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: How this, ask think person. Cuz said wishing show cared true, might feel suppressed cornered.
# Error 6032
# Content:  bio mother really feed malnourished mentally traumatized
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: bio mother really feed malnourished mentally traumatized
# Error 6035
# Content:  want take shower even want fucking move wana sit here. sleep goddamn computrer chair, fuck head. icant stop thinking
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: want take shower even want fucking move wana sit here. sleep goddamn computrer chair, fuck head. icant stop thinking
# Error 6051
# Content:  father abused anxiety med go rehab getting duo
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 1 1 1 0]
# Content: father abused anxiety med go rehab getting duo
# Error 6053
# Content:  Care I get sleep bout 7am, dream vision went black head fuzzy, woke head dizzy fuzzy thought coma. It really freaked wondering idea meant..? I overly tired past 2 weeks, happened last night
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 1 0 0 0 0 0]
# Content: Care I get sleep bout 7am, dream vision went black head fuzzy, woke head dizzy fuzzy thought coma. It really freaked wondering idea meant..? I overly tired past 2 weeks, happened last night
# Error 6060
# Content:  Urgh turn rant Had bad night, much sleep. At work right clear ton report .
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 1 0 1 1 0 0]
# Content: Urgh turn rant Had bad night, much sleep. At work right clear ton report .
# Error 6071
# Content:  Care Okay so... big sister talk much got phone started 9th grade last autumn beginning. She keep talking friend lot time busy night sleep. And even give excuse like late work talk le ever. I feel lonely without soulmate friend talk quarantine times.
# True labels:  [0 0 0 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Care Okay so... big sister talk much got phone started 9th grade last autumn beginning. She keep talking friend lot time busy night sleep. And even give excuse like late work talk le ever. I feel lonely without soulmate friend talk quarantine times.
# Error 6078
# Content:  I read Text but... 4 hour sleep focused... ended like?
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I read Text but... 4 hour sleep focused... ended like?
# Error 6079
# Content:  really hard find energy motivation go school sometimes, especially make anxious, keep reassuring okay. much, trying put mind ease help make le irrational decision work better afraid ask teacher help either, help you, even one one catch yknow? understand may embarassing, help long run
# True labels:  [0 0 1 0 1 0 0]
# Predicted labels:  [0 0 1 1 1 0 0]
# Content: really hard find energy motivation go school sometimes, especially make anxious, keep reassuring okay. much, trying put mind ease help make le irrational decision work better afraid ask teacher help either, help you, even one one catch yknow? understand may embarassing, help long run
# Error 6083
# Content:  got make connections, I know hard ok. there, sometimes I would think I would want meet anyone new, stay home play video game
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: got make connections, I know hard ok. there, sometimes I would think I would want meet anyone new, stay home play video game
# Error 6091
# Content:  Iodine know. I need go I social hang brother
# True labels:  [0 1 1 0 0 0 0]
# Predicted labels:  [0 0 1 0 0 0 0]
# Content: Iodine know. I need go I social hang brother
# Error 6118
# Content:  Kindly use channel anything purpose support others. Take conversation lounge people cannot use advice wait someone else come help discus whether person asking help blame problem regardless consist not.
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Kindly use channel anything purpose support others. Take conversation lounge people cannot use advice wait someone else come help discus whether person asking help blame problem regardless consist not.
# Error 6119
# Content:  You forget goddamn thing cause great distress life honestly sit telling I need move like easy even remotely possible time soon
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: You forget goddamn thing cause great distress life honestly sit telling I need move like easy even remotely possible time soon
# Error 6121
# Content:  sometimes people ignore others know say want say anything want hurt
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: sometimes people ignore others know say want say anything want hurt
# Error 6140
# Content:  kept talking guy saying look lot better
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: kept talking guy saying look lot better
# Error 6147
# Content:  Care past day absolutely fucking horrible. think got better ignoring bad thoughts, come attack hate anything. everything want distract going get anywhere, especially nothing discouragement. hate everything
# True labels:  [0 0 0 1 0 1 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: Care past day absolutely fucking horrible. think got better ignoring bad thoughts, come attack hate anything. everything want distract going get anywhere, especially nothing discouragement. hate everything
# Error 6148
# Content:  everyone way things, blatantly said ping stupid.
# True labels:  [0 0 0 1 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: everyone way things, blatantly said ping stupid.
# Error 6155
# Content:  Makes feel like I die, plus I like seeing blood reason. I commend schooltime therapist found out.
# True labels:  [0 0 0 0 1 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Makes feel like I die, plus I like seeing blood reason. I commend schooltime therapist found out.
# Error 6158
# Content:  excited go back school see people like one people excited see afraid honest afraid get crush him, last thing want. like, total bitch, would feel pathetic fall guy nice
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: excited go back school see people like one people excited see afraid honest afraid get crush him, last thing want. like, total bitch, would feel pathetic fall guy nice
# Error 6161
# Content:  even knew I asked preferred share bed
# True labels:  [0 1 0 0 0 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: even knew I asked preferred share bed
# Error 6174
# Content:  drank like half bottle whiskey cried porch day
# True labels:  [0 0 1 0 0 0 0]
# Predicted labels:  [0 0 0 1 0 0 0]
# Content: drank like half bottle whiskey cried porch day
# Error 6178
# Content:  Well thing start getting tense, I would say best bet leave, honest.
# True labels:  [0 0 0 0 0 0 1]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: Well thing start getting tense, I would say best bet leave, honest.
# Error 6186
# Content:  I know I would like word distraction even though exactly I would probably need.
# True labels:  [0 0 0 0 1 0 0]
# Predicted labels:  [0 0 0 0 0 0 0]
# Content: I know I would like word distraction even though exactly I would probably need.

# %%
class TFBertModelWithAttention(TFBertModel):
    def call(self, inputs, **kwargs):
        outputs = self.bert(inputs, **kwargs)
        attention = outputs[-1]
        return outputs, attention
from transformers import TFBertForSequenceClassification, BertTokenizer

tokenizer = BertTokenizer.from_pretrained('publichealthsurveillance/PHS-BERT')
model = TFBertForSequenceClassification.from_pretrained('publichealthsurveillance/PHS-BERT', from_pt=True)
bert_model = TFBertModelWithAttention.from_pretrained('publichealthsurveillance/PHS-BERT', from_pt=True)

# Get the attention weights for a single input (e.g., the first input in the test set)
input_id = tf.reshape(test_input_ids[0], (1, -1))
attention_mask = tf.reshape(test_attention_masks[0], (1, -1))

# Extract the attention weights
outputs, attention_weights = bert_model(input_id, attention_mask=attention_mask, output_attentions=True)
#_, _, attention_weights = bert_model(input_id, attention_mask=attention_mask, output_attentions=True)

attention_weights = np.array([aw.numpy() for aw in attention_weights])

# print(attention_weights.shape)

def select_top_heads(attention_weights, num_top_heads, layers_to_consider):
    num_layers, _, num_heads, _, _ = attention_weights.shape
    average_weights = np.mean(attention_weights, axis=(3, 4))

    # Only consider the layers specified in layers_to_consider
    weights_to_consider = average_weights[layers_to_consider, 0, :]
    top_heads_indices = np.argsort(weights_to_consider.ravel())[-num_top_heads:]
    top_heads = [(layers_to_consider[idx // num_heads], idx % num_heads) for idx in top_heads_indices]

    return top_heads

# Example usage:
num_top_heads = 5
layers_to_consider = [0, 11]  # Indices of layers 1 and 12

selected_heads = select_top_heads(attention_weights, num_top_heads, layers_to_consider)
print(selected_heads)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModelWithAttention: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'bert.embeddings.position_ids', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModelWithAttention from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModelWithAttention from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModelWithAttention were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [(0, 3), (0, 2), (0, 1), (11, 14), (11, 15)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, TFAutoModel

tokenizer = AutoTokenizer.from_pretrained('publichealthsurveillance/PHS-BERT')
bert_model = TFAutoModel.from_pretrained('publichealthsurveillance/PHS-BERT', from_pt=True)

# sample_sentence = "Can't sleep, always tired, hard to focus."
sample_sentence = "Lost appetite, feel guilty, thinking of ending it."

bert_tokens = tokenizer.encode_plus(sample_sentence, add_special_tokens=True, return_tensors="tf")
bert_outputs = bert_model(bert_tokens['input_ids'], attention_mask=bert_tokens['attention_mask'], output_attentions=True)
bert_attention = bert_outputs.attentions

def plot_attention(tokens, attention, layer, head):
    plt.figure(figsize=(10, 10))
    tokens = tokenizer.convert_ids_to_tokens(tokens.numpy()[0])
    attention_values = attention[layer][0, head].numpy()
    print(f"Attention values (Layer {layer + 1}, Head {head + 1}):")
    print(np.round(attention_values, decimals=4))
    ax = sns.heatmap(attention_values, xticklabels=False, yticklabels=False, cmap='viridis', annot=False)
    ax.xaxis.tick_top()
    plt.xlabel("Key")
    plt.ylabel("Query")
    plt.title(f"Layer {layer + 1}, Head {head + 1}")
    plt.show()

selected_heads = [(0, 3), (0, 2), (0, 1), (11, 14), (11, 15)]

for layer, head in selected_heads:
  print(f"BERT Attention Visualization for Layer {layer + 1}, Head {head + 1}:")
  plot_attention(bert_tokens['input_ids'], bert_attention, layer, head)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'bert.embeddings.position_ids', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERT Attention Visualization for Layer 1, Head 4:
# Attention values (Layer 1, Head 4):
# [[0.1948 0.0308 0.0216 0.0429 0.0498 0.0107 0.0438 0.0782 0.1035 0.0082
#   0.0248 0.0721 0.3188]
#  [0.1118 0.0728 0.1392 0.0698 0.0798 0.1199 0.0703 0.0257 0.0399 0.0671
#   0.0896 0.0354 0.0786]
#  [0.2189 0.0564 0.0802 0.0404 0.0551 0.0381 0.0511 0.0434 0.1003 0.0224
#   0.0852 0.0571 0.1511]
#  [0.0076 0.0132 0.0066 0.0999 0.024  0.0044 0.1302 0.0241 0.0104 0.0058
#   0.007  0.0505 0.6164]
#  [0.1674 0.0548 0.0409 0.0549 0.0302 0.1    0.0756 0.0202 0.0364 0.0334
#   0.0601 0.0691 0.2571]
#  [0.2113 0.0367 0.045  0.0288 0.1188 0.126  0.0276 0.0308 0.1262 0.0885
#   0.0467 0.0331 0.0805]
#  [0.0065 0.0093 0.0041 0.1121 0.0242 0.0031 0.1194 0.0216 0.0099 0.0039
#   0.0058 0.0478 0.6322]
#  [0.1111 0.0328 0.0764 0.0262 0.1781 0.1965 0.0466 0.0214 0.0323 0.1469
#   1.500e-03 8.000e-04 8.000e-03 3.700e-03 6.400e-02 2.348e-01]
#  [3.150e-01 1.860e-02 7.380e-02 3.850e-02 2.250e-02 4.770e-02 5.400e-02
#   2.420e-02 2.110e-02 4.430e-02 2.710e-02 1.305e-01 1.827e-01]
#  [4.081e-01 1.440e-02 9.610e-02 1.240e-02 2.010e-02 6.550e-02 1.750e-02
#   1.090e-02 1.360e-02 1.476e-01 2.890e-02 4.630e-02 1.185e-01]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, TFAutoModel

tokenizer = AutoTokenizer.from_pretrained('publichealthsurveillance/PHS-BERT')
bert_model = TFAutoModel.from_pretrained('publichealthsurveillance/PHS-BERT', from_pt=True)

sample_sentence = "Can't sleep, always tired, hard to focus."
# sample_sentence = "Lost appetite, feel guilty, thinking of ending it."

bert_tokens = tokenizer.encode_plus(sample_sentence, add_special_tokens=True, return_tensors="tf")
bert_outputs = bert_model(bert_tokens['input_ids'], attention_mask=bert_tokens['attention_mask'], output_attentions=True)
bert_attention = bert_outputs.attentions

def plot_attention(tokens, attention, layer, head):
    plt.figure(figsize=(10, 10))
    tokens = tokenizer.convert_ids_to_tokens(tokens.numpy()[0])
    attention_values = attention[layer][0, head].numpy()
    print(f"Attention values (Layer {layer + 1}, Head {head + 1}):")
    print(np.round(attention_values, decimals=4))
    ax = sns.heatmap(attention_values, xticklabels=False, yticklabels=False, cmap='viridis', annot=False)
    ax.xaxis.tick_top()
    plt.xlabel("Key")
    plt.ylabel("Query")
    plt.title(f"Layer {layer + 1}, Head {head + 1}")
    plt.show()

selected_heads = [(0, 3), (0, 2), (0, 1), (11, 14), (11, 15)]

for layer, head in selected_heads:
  print(f"BERT Attention Visualization for Layer {layer + 1}, Head {head + 1}:")
  plot_attention(bert_tokens['input_ids'], bert_attention, layer, head)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'bert.embeddings.position_ids', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERT Attention Visualization for Layer 1, Head 4:
# Attention values (Layer 1, Head 4):
# [[0.1801 0.0557 0.0228 0.0973 0.0296 0.0411 0.0347 0.0094 0.0368 0.0246
#   0.0795 0.0128 0.0654 0.3103]
#  [0.0605 0.0353 0.0499 0.033  0.0366 0.1197 0.0626 0.0551 0.1378 0.0476
#   0.0306 0.076  0.0575 0.1978]
#  [0.1655 0.0495 0.0131 0.0191 0.0071 0.0768 0.0432 0.0287 0.0682 0.0179
#   0.0424 0.0164 0.0324 0.4197]
#  [0.0921 0.0806 0.0757 0.0093 0.0208 0.0571 0.0388 0.0273 0.0542 0.0184
#   0.0468 0.0569 0.0308 0.3914]
#  [0.2493 0.0696 0.032  0.0126 0.089  0.02   0.0612 0.1    0.0156 0.1589
#   0.0498 0.0856 0.0173 0.0391]
#  [0.0068 0.0094 0.0284 0.0083 0.0066 0.1166 0.0092 0.0098 0.1059 0.005
#   0.0085 0.0068 0.0446 0.634 ]
